# %%
import torch
import pandas as pd

# %% [markdown]
# ### DE-En module

# %%
# load pre-trained En→De translation module

en2de = torch.hub.load('pytorch/fairseq', 'transformer.wmt19.en-de.single_model')
en2de.cuda()
# Out:
# Using cache found in /home/docando/.cache/torch/hub/pytorch_fairseq_master
# GeneratorHubInterface(
#   (models): ModuleList(
#     (0): TransformerModel(
#       (encoder): TransformerEncoder(
#         (dropout_module): FairseqDropout()
#         (embed_tokens): Embedding(42024, 1024, padding_idx=1)
#         (embed_positions): SinusoidalPositionalEmbedding()
#         (layers): ModuleList(
#           (0): TransformerEncoderLayer(
#             (self_attn): MultiheadAttention(
#               (dropout_module): FairseqDropout()
#               (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             )
#             (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
# ...

# %%
# 동작 test
en2de.translate('Hello world', beam=5)
# Out:
# 'Hallo Welt'

# %% [markdown]
# ### En-De module

# %%
# load pre-trained De→En translation module

de2en = torch.hub.load('pytorch/fairseq', 'transformer.wmt19.de-en.single_model')
de2en.cuda()
# Out:
# Using cache found in /home/docando/.cache/torch/hub/pytorch_fairseq_master
# GeneratorHubInterface(
#   (models): ModuleList(
#     (0): TransformerModel(
#       (encoder): TransformerEncoder(
#         (dropout_module): FairseqDropout()
#         (embed_tokens): Embedding(42024, 1024, padding_idx=1)
#         (embed_positions): SinusoidalPositionalEmbedding()
#         (layers): ModuleList(
#           (0): TransformerEncoderLayer(
#             (self_attn): MultiheadAttention(
#               (dropout_module): FairseqDropout()
#               (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (out_proj): Linear(in_features=1024, out_features=1024, bias=True)
#             )
#             (self_attn_layer_norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
# ...

# %%
# 동작 test
de2en.translate('Hallo Welt', beam=5)
# Out:
# 'Hello World'

# %% [markdown]
# ### En-Ru Module

# %%
# load pre-trained En→De translation module

en2ru = torch.hub.load('pytorch/fairseq', 'transformer.wmt19.en-ru.single_model')
en2ru.cuda()
# Out:
# Using cache found in /home/docando/.cache/torch/hub/pytorch_fairseq_master
#
# ...
#  28%|██▊       | 854633472/3037373614 [01:15<03:12, 11330033.27B/s]
# ...
# ...
# 100%|██████████| 3037373614/3037373614 [04:27<00:00, 11352358.46B/s][A
# GeneratorHubInterface(
#   (models): ModuleList(
#     (0): TransformerModel(
#       (encoder): TransformerEncoder(
#         (dropout_module): FairseqDropout()
#         (embed_tokens): Embedding(31640, 1024, padding_idx=1)
#         (embed_positions): SinusoidalPositionalEmbedding()
#         (layers): ModuleList(
#           (0): TransformerEncoderLayer(
#             (self_attn): MultiheadAttention(
#               (dropout_module): FairseqDropout()
#               (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
# ...

# %%
# 동작 test
en2ru.translate('Hello world', beam=5)
# Out:
# 'Мир ада'

# %% [markdown]
# ### Ru-En Module

# %%
# load pre-trained En→De translation module

ru2en = torch.hub.load('pytorch/fairseq', 'transformer.wmt19.ru-en.single_model')
ru2en.cuda()
# Out:
# Using cache found in /home/docando/.cache/torch/hub/pytorch_fairseq_master
#
# ...
#  28%|██▊       | 864333824/3041223502 [01:15<03:08, 11555540.44B/s]
# ...
# ...
# 100%|██████████| 3041223502/3041223502 [04:24<00:00, 11497698.01B/s][A
# GeneratorHubInterface(
#   (models): ModuleList(
#     (0): TransformerModel(
#       (encoder): TransformerEncoder(
#         (dropout_module): FairseqDropout()
#         (embed_tokens): Embedding(31232, 1024, padding_idx=1)
#         (embed_positions): SinusoidalPositionalEmbedding()
#         (layers): ModuleList(
#           (0): TransformerEncoderLayer(
#             (self_attn): MultiheadAttention(
#               (dropout_module): FairseqDropout()
#               (k_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (v_proj): Linear(in_features=1024, out_features=1024, bias=True)
#               (q_proj): Linear(in_features=1024, out_features=1024, bias=True)
# ...

# %%
ru2en.translate('Мир ада', beam=5)
# Out:
# 'The World of Hell'

# %% [markdown]
# ### Data Load

# %%
def load_data():
    train = pd.read_csv("../data/train_final.csv")
    eval = pd.read_csv("../data/eval_final_open.csv")
    train_X = train['Sentence'] # 본문 내용을 기준으로 분류하기
    train_Y = train['Category']
    eval_X = eval['Sentence']
    return train_X, train_Y, eval_X

# %%
train_x, train_y, test_x = load_data()

# %%
train_x
# Out:
# 0        -LRB- The film -RRB- tackles the topic of rela...
# 1                    Lavishly , exhilaratingly tasteless .
# 2                           It is also beautifully acted .
# 3        But , like Silence , it 's a movie that gets u...
# 4        It 's been made with an innocent yet fervid co...
#                                ...
# 11539    Although Frailty fits into a classic genre , i...
# 11540                   Mediocre fable from Burkina Faso .
# 11541    Like all great films about a life you never kn...
# 11542    Those who are n't put off by the film 's auste...
# 11543    An ambitious movie that , like Shiner 's organ...
# Name: Sentence, Length: 11544, dtype: object

# %% [markdown]
# ### Translation

# %%
# EN -> DE

en2de_train_x = en2de.translate(train_x, beam=5)

# %%
en2de_train_x

# %%
# De -> En

de2en_train_x = de2en.translate(en2de_train_x, beam=5)

# %%
de2en_train_x

# %%
# EN -> Ru

en2ru_train_x = en2ru.translate(train_x, beam=5)

# %%
en2ru_train_x

# %%
# Ru -> En

ru2en_train_x = ru2en.translate(en2ru_train_x, beam=5)

# %%
ru2en_train_x

# %% [markdown]
# ### save augmented file

# %%
train_y_li = train_y.to_list()

# %%
# 새로운 데이터 생성 for De-En

de_data_dict = {'Category': train_y_li, 'Sentence': de2en_train_x}
df = pd.DataFrame(data_dict)

# %%
df.to_csv('../data/augmented/train_x_de2en.csv', header = 'True')

# %%
# 새로운 데이터 생성 for Ru-En

ru_data_dict = {'Category': train_y_li, 'Sentence': ru2en_train_x}
df = pd.DataFrame(data_dict)

# %%
df.to_csv('../data/augmented/train_x_ru2en.csv', header = 'True')
